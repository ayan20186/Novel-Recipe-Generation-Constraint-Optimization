# %%
# !pip install gensim
# !pip install fasttext
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.3)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pybind11>=2.2 (from fasttext)
#   Using cached pybind11-2.11.1-py3-none-any.whl (227 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.23.5)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4199772 sha256=12704e18e9b2f93d19e0fedce7e76d39e74fe4e1b58ec60e60c296fe6230b469
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.2 pybind11-2.11.1

# %%
import pandas as pd
import numpy as np
import json
import joblib as jb
import re
import ast
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import gensim.downloader as api
import gensim
from gensim.models import FastText
import fasttext
from huggingface_hub import hf_hub_download

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
df_new = jb.load('/content/drive/MyDrive/BTP: Novel Recipe Generation (Constraint Optimization) 2023/Data/Preprocessed/data_v1.pickle')

# %%
df = pd.DataFrame(df_new)

# %% [markdown]
# **Formatting the Instructions of the Recipe by Performing operations like removing '\t' from the beginning of the instructions, inserting ';' at the end of each instruction, etc**

# %%
list_of_instrns = []
for row in range(0,len(df)):
    instr = df.iloc[row]['instructions']

    strg = ""
    length = len(instr) - 1
    count = 0
    for instruction in instr:
        processed_instr = []
        for j in range(0,len(instruction)):
            if(instruction[j]=='|' or instruction[j]=='\t'):
                continue
            elif(instruction[j]==' '):
                if(instruction[j-1]!='|'):
                   strg = strg + instruction[j]
            elif(instruction[j] == '.') and (j!=len(instruction)-1) and (instruction[j-1].isdigit()==False):
                strg = strg + ' '
                strg = strg + instruction[j]
            elif(instruction[j]>='a' and instruction[j]<='z') or (instruction[j]>='A' and instruction[j]<='Z') :
                 strg =  strg + instruction[j].lower()
            elif(instruction[j] == ','):
                  strg =  strg + ' '
                  strg =  strg + ','
            elif(instruction[j].isdigit()):
                if(instruction[j+1] == '.') or (instruction[j+2] == '.'):
                    continue
                else:
                    strg = strg + instruction[j]

        if(count!=length):
            strg = strg + ' '
            strg = strg + ';'
            strg = strg + ' '


        count = count + 1

    processed_instr.append(strg)
    list_of_instrns.append(processed_instr)

# %% [markdown]
# **Deleting the current "instructions" column from the DataFrame and inserting the modified Instructions by Creating the new "instructions" column**

# %%
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]

    return tokens

# %%
df.drop('instructions', inplace=True, axis=1)

# %%
df['instructions'] = list_of_instrns

# %%
df_top5 = df[df['region'].isin(['Italian', 'Mexican', 'South American', 'Canadian', 'Indian Subcontinent'])]

# %%
df_top5['preprocessed_title'] = df_top5['title'].apply(preprocess_text)
df_top5['preprocessed_ingredients'] = df_top5['ingredients'].apply(lambda x: [preprocess_text(ingredient) for ingredient in x])
df_top5['preprocessed_instructions'] = df_top5['instructions'].apply(lambda x: [preprocess_text(instruction) for instruction in x])

df_top5[['title', 'preprocessed_title', 'ingredients', 'preprocessed_ingredients', 'instructions', 'preprocessed_instructions']].head()
# Out:
# <ipython-input-12-24d2780f423b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_top5['preprocessed_title'] = df_top5['title'].apply(preprocess_text)
# <ipython-input-12-24d2780f423b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_top5['preprocessed_ingredients'] = df_top5['ingredients'].apply(lambda x: [preprocess_text(ingredient) for ingredient in x])
# <ipython-input-12-24d2780f423b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_top5['preprocessed_instructions'] = df_top5['instructions'].apply(lambda x: [preprocess_text(instruction) for instruction in x])
#                                    title  \
# 1087     Spicy Crab Curry - Bangla Style
# 1088  Machhere Jhol (Bengali Fish Curry)
# 1089                Egg and Potato Curry
# 1090                   Butter Lamb Gravy
# 1091                        Beef Samosas
#
#                           preprocessed_title  \
# 1087     [spicy, crab, curry, bangla, style]
# 1088  [machhere, jhol, bengali, fish, curry]
# 1089                    [egg, potato, curry]
# 1090                   [butter, lamb, gravy]
# 1091                         [beef, samosas]
#
#                                             ingredients  \
# 1087  [mustard seed, water, mustard oil, clove, caye...
# 1088  [mustard seed, water, turmeric, fennel seed, c...
# 1089  [garam masala, ginger paste, water, turmeric, ...
# 1090  [garam masala, water, turmeric, ginger, tomato...
# 1091  [beef, phyllo dough, cumin seed, pea, coriande...
#
#                                preprocessed_ingredients  \
# 1087  [[mustard, seed], [water], [mustard, oil], [cl...
# 1088  [[mustard, seed], [water], [turmeric], [fennel...
# 1089  [[garam, masala], [ginger, paste], [water], [t...
# 1090  [[garam, masala], [water], [turmeric], [ginger...
# 1091  [[beef], [phyllo, dough], [cumin, seed], [pea]...
#
#                                            instructions  \
# 1087  [rub the crabs with 1 teaspoon of the turmeric...
# 1088  [bring the tomatoes , cumin , turmeric , salt ...
# 1089  [heat 1 tablespoon oil in a skillet over mediu...
# 1090  [season the lamb with garam masala and salt . ...
# 1091  [bring a medium saucepan of lightly salted wat...
#
#                               preprocessed_instructions
# 1087  [[rub, crabs, teaspoon, turmeric, teaspoon, sa...
# 1088  [[bring, tomatoes, cumin, turmeric, salt, wate...
# 1089  [[heat, tablespoon, oil, skillet, medium, heat...
# 1090  [[season, lamb, garam, masala, salt, heat, tab...
# 1091  [[bring, medium, saucepan, lightly, salted, wa...

# %%
sentences = []
for index, row in df_top5.iterrows():
    for title_list in row['preprocessed_title']:
        t = []
        t.append(title_list)
        sentences.append(t)
    for ingredient_list in row['preprocessed_ingredients']:
        for ingredient in ingredient_list:
            sentences.append(ingredient.split())
    for instruction_list in row['preprocessed_instructions']:
        for instruction in instruction_list:
            sentences.append(instruction.split())
sentences
# Out:
# [['spicy'],
#  ['crab'],
#  ['curry'],
#  ['bangla'],
#  ['style'],
#  ['mustard'],
#  ['seed'],
#  ['water'],
#  ['mustard'],
#  ['oil'],
#  ['clove'],
#  ['cayenne'],
#  ['pepper'],
#  ['black'],
#  ['peppercorn'],
#  ['garlic'],
#  ['paste'],
#  ['turmeric'],
#  ['cinnamon'],
#  ['white'],
#  ['sugar'],
#  ['cilantro'],
#  ['garnish'],
#  ['ginger'],
#  ['paste'],
#  ['thai'],
#  ['green'],
#  ['chile'],
#  ['potato'],
#  ['lengthwise'],
#  ['tomato'],
#  ['green'],
#  ['cardamom'],
#  ['pod'],
#  ['salt'],
#  ['dungeness'],
#  ['crab'],
#  ['red'],
#  ['onion'],
#  ['wedge'],
#  ['lemon'],
#  ['rub'],
#  ['crabs'],
#  ['teaspoon'],
#  ['turmeric'],
#  ['teaspoon'],
#  ['salt'],
#  ['let'],
#  ['marinate'],
#  ['hour'],
#  ['combine'],
#  ['mustard'],
#  ['seed'],
#  ['hot'],
#  ['water'],
#  ['small'],
#  ['bowl'],
#  ['let'],
#  ['stand'],
#  ['minutes'],
#  ['use'],
#  ['mortar'],
#  ['pestle'],
#  ['grind'],
#  ['seeds'],
#  ['coarse'],
#  ['paste'],
#  ['heat'],
#  ['oil'],
#  ['wok'],
#  ['kadhai'],
#  ['medium'],
#  ['heat'],
#  ['add'],
#  ['crabs'],
#  ['stir'],
#  ['fry'],
#  ['change'],
#  ['color'],
#  ['minutes'],
#  ['remove'],
#  ['crabs'],
#  ['oil'],
#  ['set'],
#  ['aside'],
#  ['add'],
#  ['sliced'],
#  ['onions'],
#  ['wok'],
#  ['cook'],
#  ['stir'],
#  ['medium'],
#  ['heat'],
#  ['onions'],
#  ['translucent'],
#  ['minutes'],
#  ['raise'],
#  ['heat'],
#  ['high'],
#  ['add'],
#  ['potatoes'],
#  ['cook'],
#  ['stirring'],
#  ['constantly'],
#  ['minutes'],
#  ['add'],
#  ['cloves'],
#  ['cinnamon'],
#  ['stick'],
#  ['cardamom'],
#  ['pods'],
#  ['peppercorns'],
#  ['stir'],
#  ['thirty'],
#  ['seconds'],
#  ['stir'],
#  ['tomatoes'],
#  ['ginger'],
#  ['paste'],
#  ['garlic'],
#  ['paste'],
#  ['halve'],
#  ['three'],
#  ['chiles'],
#  ['add'],
#  ['wok'],
#  ['cook'],
#  ['stir'],
#  ['additional'],
#  ['minute'],
#  ['two'],
#  ['high'],
#  ['heat'],
#  ['reduce'],
#  ['heat'],
#  ['medium'],
#  ['add'],
#  ['remaining'],
#  ['teaspoon'],
#  ['turmeric'],
#  ['cayenne'],
#  ['pepper'],
#  ['mustard'],
#  ['paste'],
#  ['stir'],
#  ['combine'],
#  ['add'],
#  ['crabs'],
#  ['wok'],
#  ['pour'],
#  ['enough'],
#  ['water'],
#  ['cover'],
#  ['vegetables'],
#  ['bring'],
#  ['water'],
#  ['boil'],
#  ['stir'],
#  ['sugar'],
#  ['salt'],
#  ['taste'],
#  ['cover'],
#  ['wok'],
#  ['reduce'],
#  ['heat'],
#  ['simmer'],
#  ['potatoes'],
#  ['tender'],
#  ['water'],
#  ['reduced'],
#  ['half'],
#  ['minutes'],
#  ['remove'],
#  ['lid'],
#  ['stir'],
#  ['simmer'],
#  ['gravy'],
#  ['thickened'],
#  ['minutes'],
#  ['squeeze'],
#  ['lemon'],
#  ['wedge'],
#  ['finished'],
#  ['dish'],
#  ['garnish'],
#  ['chopped'],
#  ['cilantro'],
#  ['sliced'],
#  ['green'],
#  ['chile'],
#  ['serve'],
#  ['hot'],
#  ['rice'],
#  ['machhere'],
#  ['jhol'],
#  ['bengali'],
#  ['fish'],
#  ['curry'],
#  ['mustard'],
#  ['seed'],
#  ['water'],
#  ['turmeric'],
#  ['fennel'],
#  ['seed'],
#  ['cumin'],
#  ['seed'],
#  ['vegetable'],
#  ['oil'],
#  ['fenugreek'],
#  ['seed'],
#  ['tomato'],
#  ['cumin'],
#  ['black'],
#  ['cumin'],
#  ['seed'],
#  ['whitefish'],
#  ['fillet'],
#  ['salt'],
#  ['bring'],
#  ['tomatoes'],
#  ['cumin'],
#  ['turmeric'],
#  ['salt'],
#  ['water'],
#  ['boil'],
#  ['four'],
#  ['quart'],
#  ['saucepan'],
#  ['reduce'],
#  ['heat'],
#  ['medium'],
#  ['maintain'],
#  ['simmer'],
#  ['heat'],
#  ['oil'],
#  ['skillet'],
#  ['medium'],
#  ['high'],
#  ['heat'],
#  ['cook'],
#  ['fish'],
#  ['oiled'],
#  ['skillet'],
#  ['golden'],
#  ['brown'],
#  ['minutes'],
#  ['per'],
#  ['side'],
#  ['transfer'],
#  ['fish'],
#  ['saucepan'],
#  ['heat'],
#  ['separate'],
#  ['skillet'],
#  ['medium'],
#  ['heat'],
#  ['toast'],
#  ['mustard'],
#  ['seeds'],
#  ['cumin'],
#  ['seeds'],
#  ['black'],
#  ['cumin'],
#  ['seeds'],
#  ['fennel'],
#  ['seeds'],
#  ['fenugreek'],
#  ['seeds'],
#  ['fragrant'],
#  ['seconds'],
#  ['stir'],
#  ['spices'],
#  ['saucepan'],
#  ['simmer'],
#  ['flavors'],
#  ['integrate'],
#  ['minutes'],
#  ['serve'],
#  ['hot'],
#  ['egg'],
#  ['potato'],
#  ['curry'],
#  ['garam'],
#  ['masala'],
#  ['ginger'],
#  ['paste'],
#  ['water'],
#  ['turmeric'],
#  ['vegetable'],
#  ['oil'],
#  ['cayenne'],
#  ['pepper'],
#  ['tomato'],
#  ['cumin'],
#  ['potato'],
#  ['egg'],
#  ['green'],
#  ['chile'],
#  ['pepper'],
#  ['cilantro'],
#  ['garlic'],
#  ['paste'],
#  ['salt'],
#  ['coriander'],
#  ['onion'],
#  ['heat'],
#  ['tablespoon'],
#  ['oil'],
#  ['skillet'],
#  ['medium'],
#  ['heat'],
#  ['stir'],
#  ['onions'],
#  ['cook'],
#  ['stir'],
#  ['onion'],
#  ['pieces'],
#  ['soft'],
#  ['translucent'],
#  ['minutes'],
#  ['reduce'],
#  ['heat'],
#  ['medium'],
#  ['low'],
#  ['continue'],
#  ['cooking'],
#  ['stirring'],
#  ['occasionally'],
#  ['onions'],
#  ['golden'],
#  ['minutes'],
#  ['remove'],
#  ['pan'],
#  ['heat'],
#  ['set'],
#  ['aside'],
#  ['transfer'],
#  ['cooked'],
#  ['onions'],
#  ['bowl'],
#  ['food'],
#  ['processor'],
#  ['grind'],
#  ['onions'],
#  ['tomatoes'],
#  ['green'],
#  ['chiles'],
#  ['smooth'],
#  ['paste'],
#  ['heat'],
#  ['remaining'],
#  ['tablespoons'],
#  ['oil'],
#  ['skillet'],
#  ['medium'],
#  ['heat'],
#  ['add'],
#  ['onion'],
#  ['mixture'],
#  ['carefully'],
#  ['may'],
#  ['spatter'],
#  ['cook'],
#  ['stir'],
#  ['minutes'],
#  ['stir'],
#  ['garlic'],
#  ['paste'],
#  ['ginger'],
#  ['paste'],
#  ['coriander'],
#  ['cumin'],
#  ['garam'],
#  ['masala'],
#  ['turmeric'],
#  ['cayenne'],
#  ['pepper'],
#  ['salt'],
#  ['cook'],
#  ['stir'],
#  ['oil'],
#  ['begins'],
#  ['separate'],
#  ['mixture'],
#  ['minutes'],
#  ['pour'],
#  ['water'],
#  ['skillet'],
#  ['bring'],
#  ['sauce'],
#  ['boil'],
#  ['add'],
#  ['cubed'],
#  ['potatoes'],
#  ['gently'],
#  ['stir'],
#  ['eggs'],
#  ['reduce'],
#  ['heat'],
#  ['low'],
#  ['simmer'],
#  ['sauce'],
#  ['thickened'],
#  ['slightly'],
#  ['minutes'],
#  ['remove'],
#  ['heat'],
#  ['garnish'],
#  ['cilantro'],
#  ['serving'],
#  ['butter'],
#  ['lamb'],
#  ['gravy'],
#  ['garam'],
#  ['masala'],
#  ['water'],
#  ['turmeric'],
#  ['ginger'],
#  ['tomato'],
#  ['paste'],
#  ['cayenne'],
#  ['pepper'],
#  ['heavy'],
#  ['cream'],
#  ['cilantro'],
#  ['butter'],
#  ['honey'],
#  ['salt'],
#  ['onion'],
#  ['lamb'],
#  ['shoulder'],
#  ['garlic'],
#  ['season'],
#  ['lamb'],
#  ['garam'],
#  ['masala'],
#  ['salt'],
#  ['heat'],
#  ['tablespoon'],
#  ['butter'],
#  ['large'],
#  ['skillet'],
#  ['medium'],
#  ['heat'],
#  ['fry'],
#  ['lamb'],
#  ['cubes'],
#  ['browned'],
#  ['stirring'],
#  ['constantly'],
#  ['remove'],
#  ['skillet'],
#  ['set'],
#  ['aside'],
#  ['melt'],
#  ['remaining'],
#  ['butter'],
#  ['skillet'],
#  ['medium'],
#  ['heat'],
#  ['add'],
#  ['onion'],
#  ['cook'],
#  ['stir'],
#  ['onion'],
#  ['softened'],
#  ['turned'],
#  ['translucent'],
#  ['minutes'],
#  ['stir'],
#  ['turmeric'],
#  ['ginger'],
#  ['garlic'],
#  ['cook'],
#  ['stir'],
#  ['minute'],
#  ['stir'],
#  ['cayenne'],
#  ['tomato'],
#  ['paste'],
#  ['well'],
#  ['blended'],
#  ['stir'],
#  ['water'],
#  ['bring'],
#  ['simmer'],
#  ['return'],
#  ['lamb'],
#  ['skillet'],
#  ['simmer'],
#  ['low'],
#  ['heat'],
#  ['minutes'],
#  ['lamb'],
#  ['tender'],
#  ['stir'],
#  ['cream'],
#  ['honey'],
#  ['transfer'],
#  ['serving'],
#  ['dish'],
#  ['garnish'],
#  ['cilantro'],
#  ['beef'],
#  ['samosas'],
#  ['beef'],
#  ['phyllo'],
#  ['dough'],
#  ['cumin'],
#  ['seed'],
#  ['pea'],
#  ['coriander'],
#  ['garlic'],
#  ['turmeric'],
#  ['cinnamon'],
#  ['cilantro'],
#  ['black'],
#  ['pepper'],
#  ['vegetable'],
#  ['oil'],
#  ['green'],
#  ['chile'],
#  ['pepper'],
#  ['salt'],
#  ['bay'],
#  ['leaf'],
#  ['cardamom'],
#  ['chili'],
#  ['powder'],
#  ['potato'],
#  ['cumin'],
#  ['oil'],
#  ['ginger'],
#  ['root'],
#  ['onion'],
#  ['bring'],
#  ['medium'],
#  ['saucepan'],
#  ['lightly'],
#  ['salted'],
#  ['water'],
#  ['boil'],
#  ['stir'],
#  ['potatoes'],
#  ['peas'],
#  ['cook'],
#  ['potatoes'],
#  ['tender'],
#  ['still'],
#  ['firm'],
#  ['minutes'],
#  ['drain'],
#  ['mash'],
#  ['together'],
#  ['set'],
#  ['aside'],
#  ['large'],
#  ['saucepan'],
#  ['medium'],
#  ['high'],
#  ['heat'],
#  ['heat'],
#  ['oil'],
#  ['brown'],
#  ['cumin'],
#  ['seeds'],
#  ['bay'],
#  ['leaf'],
#  ['mix'],
#  ['onions'],
#  ['ground'],
#  ['beef'],
#  ['cook'],
#  ['beef'],
#  ['evenly'],
#  ['brown'],
#  ['onions'],
#  ['soft'],
#  ['minutes'],
#  ['mix'],
#  ['garlic'],
#  ['fresh'],
#  ['ginger'],
#  ['root'],
#  ['season'],
#  ['black'],
#  ['pepper'],
#  ['salt'],
#  ['cumin'],
#  ['coriander'],
#  ['turmeric'],
#  ['chili'],
#  ['powder'],
#  ['cinnamon'],
#  ['cardamom'],
#  ['stir'],
#  ['mashed'],
#  ['potato'],
#  ['mixture'],
#  ['remove'],
#  ['heat'],
#  ['chill'],
#  ['refrigerator'],
#  ['hour'],
#  ['cool'],
#  ['heat'],
#  ['oil'],
#  ['large'],
#  ['heavy'],
#  ['saucepan'],
#  ['high'],
#  ['heat'],
#  ['mix'],
#  ['cilantro'],
#  ['green'],
#  ['chile'],
#  ['peppers'],
#  ['potato'],
#  ['beef'],
#  ['mixture'],
#  ['place'],
#  ['approximately'],
#  ['tablespoon'],
#  ['mixture'],
#  ['onto'],
#  ['phyllo'],
#  ['sheet'],
#  ['fold'],
#  ['sheets'],
#  ['triangles'],
#  ['pressing'],
#  ['edges'],
#  ['together'],
#  ['moistened'],
#  ['fingers'],
#  ['small'],
#  ['batches'],
#  ['fry'],
#  ['golden'],
#  ['brown'],
#  ['minutes'],
#  ['drain'],
#  ['paper'],
#  ['towels'],
#  ['serve'],
#  ['warm'],
#  ['spicy'],
#  ['shrimp'],
#  ['chingri'],
#  ['maach'],
#  ['garam'],
#  ['masala'],
#  ['turmeric'],
#  ['vegetable'],
#  ['oil'],
#  ['shrimp'],
#  ['cilantro'],
#  ['leaf'],
#  ['tomato'],
#  ['green'],
#  ['chile'],
#  ['pepper'],
#  ['garlic'],
#  ['paste'],
#  ['salt'],
#  ['onion'],
#  ['heat'],
#  ['oil'],
#  ['medium'],
#  ['high'],
#  ['heat'],
#  ['large'],
#  ['skillet'],
#  ['cook'],
#  ['stir'],
#  ['onions'],
#  ['golden'],
#  ['brown'],
#  ['minutes'],
#  ['stir'],
#  ['tomato'],
#  ['cook'],
#  ['minutes'],
#  ['stir'],
#  ['garlic'],
#  ['paste'],
#  ['turmeric'],
#  ['garam'],
#  ['masala'],
#  ['green'],
#  ['chile'],
#  ['peppers'],
#  ['salt'],
#  ['cook'],
#  ['minutes'],
#  ['reduce'],
#  ['heat'],
#  ['low'],
#  ['add'],
#  ['shrimp'],
#  ['cook'],
#  ['stir'],
#  ['low'],
#  ['heat'],
#  ['shrimp'],
#  ['bright'],
#  ['pink'],
#  ['outside'],
#  ['meat'],
#  ['longer'],
#  ['transparent'],
#  ['center'],
#  ['minutes'],
#  ['add'],
#  ['small'],
#  ['amount'],
#  ['water'],
#  ['needed'],
#  ['sauce'],
#  ['thick'],
#  ['sprinkle'],
#  ['cilantro'],
#  ['gulab'],
#  ['jamun'],
#  ['kala'],
#  ['jam'],
#  ['waffle'],
#  ['balls'],
#  ['purpose'],
#  ['flour'],
#  ['yogurt'],
#  ['water'],
#  ['vegetable'],
#  ['oil'],
#  ['cardamom'],
#  ['white'],
#  ['sugar'],
#  ['saffron'],
#  ['rose'],
#  ['water'],
#  ['baking'],
#  ['soda'],
#  ['combine'],
#  ['water'],
#  ['sugar'],
#  ['cardamom'],
#  ['rose'],
#  ['water'],
#  ['saffron'],
#  ['saucepan'],
#  ['bring'],
#  ['boil'],
#  ['reduce'],
#  ['heat'],
#  ['simmer'],
#  ['consistency'],
#  ['syrupy'],
#  ['minutes'],
#  ['mix'],
#  ['milk'],
#  ['powder'],
#  ['flour'],
#  ['baking'],
#  ['soda'],
#  ['bowl'],
#  ['well'],
#  ['combined'],
#  ['slowly'],
#  ['mix'],
#  ['butter'],
#  ['yogurt'],
#  ['dough'],
#  ['comes'],
#  ['together'],
#  ['let'],
#  ['gulab'],
#  ['dough'],
#  ['rest'],
#  ['minutes'],
#  ['shape'],
#  ['smooth'],
#  ['balls'],
#  ['size'],
#  ['pennies'],
#  ['heat'],
#  ['oil'],
#  ['deep'],
#  ['fryer'],
#  ['large'],
#  ['saucepan'],
#  ['degrees'],
#  ['f'],
#  ['test'],
#  ['temperature'],
#  ['oil'],
#  ['dropping'],
#  ['small'],
#  ['piece'],
#  ['dough'],
#  ['sits'],
#  ['bottom'],
#  ['pan'],
#  ['minute'],
#  ['coming'],
#  ['surface'],
#  ['oil'],
#  ['ready'],
#  ['fry'],
#  ['gulab'],
#  ['balls'],
#  ['time'],
#  ['stirring'],
#  ['carefully'],
#  ['dark'],
#  ['golden'],
#  ['brown'],
#  ['sides'],
#  ['minutes'],
#  ['drain'],
#  ['paper'],
#  ['towel'],
#  ['lined'],
#  ['plate'],
#  ['repeat'],
#  ['remaining'],
#  ['gulab'],
#  ['bring'],
#  ['syrup'],
#  ['back'],
#  ['boil'],
#  ['drop'],
#  ['fried'],
#  ['gulab'],
#  ['remove'],
#  ['heat'],
#  ['let'],
#  ['soak'],
#  ['syrup'],
#  ['covered'],
#  ['minutes'],
#  ['hour'],
#  ['prawn'],
#  ['malai'],
#  ['curry'],
#  ['garam'],
#  ['masala'],
#  ['ginger'],
#  ['paste'],
#  ['water'],
#  ['turmeric'],
#  ['vegetable'],
#  ['oil'],
#  ['cinnamon'],
#  ['clove'],
#  ['cardamom'],
#  ['seed'],
#  ['cayenne'],
#  ['pepper'],
#  ['tomato'],
#  ['tiger'],
#  ['prawn'],
#  ['green'],
#  ['cardamom'],
#  ['pod'],
#  ['coconut'],
#  ['milk'],
#  ['garlic'],
#  ['paste'],
#  ['ghee'],
#  ['butter'],
#  ['onion'],
#  ['prepare'],
#  ['fresh'],
#  ['garam'],
#  ['masala'],
#  ['coffee'],
#  ['grinder'],
#  ['grind'],
#  ['cardamom'],
#  ['seeds'],
#  ['whole'],
#  ['cloves'],
#  ['cinnamon'],
#  ['sticks'],
#  ['fine'],
#  ['powder'],
#  ['set'],
#  ['aside'],
#  ['heat'],
#  ['vegetable'],
#  ['oil'],
#  ['skillet'],
#  ['medium'],
#  ['heat'],
#  ['add'],
#  ['whole'],
#  ['cloves'],
#  ['cardamom'],
#  ['pods'],
#  ['sticks'],
#  ['cinnamon'],
#  ['fry'],
#  ['seconds'],
#  ['stir'],
#  ['grated'],
#  ['onion'],
#  ['reduce'],
#  ['heat'],
#  ['medium'],
#  ['low'],
#  ['cook'],
#  ['stir'],
#  ['liquid'],
#  ['dries'],
#  ['onion'],
#  ['longer'],
#  ['smells'],
#  ['raw'],
#  ['minutes'],
#  ['add'],
#  ['ginger'],
#  ['paste'],
#  ['garlic'],
#  ['paste'],
#  ['cook'],
#  ['minutes'],
#  ['stirring'],
#  ['constantly'],
#  ['stir'],
#  ['turmeric'],
#  ['cayenne'],
#  ['pepper'],
#  ['add'],
#  ['chopped'],
#  ['tomatoes'],
#  ['cook'],
#  ['tomatoes'],
#  ['soft'],
#  ['minutes'],
#  ['pour'],
#  ['water'],
#  ['cover'],
#  ['pan'],
#  ['cook'],
#  ['additional'],
#  ['minutes'],
#  ['pour'],
#  ['coconut'],
#  ['milk'],
#  ['stir'],
#  ['well'],
#  ['mixture'],
#  ['boiling'],
#  ['stir'],
#  ['prawns'],
#  ['sprinkle'],
#  ['mixture'],
#  ['almost'],
#  ['fresh'],
#  ['garam'],
#  ['masala'],
#  ['powder'],
#  ['reserving'],
#  ['pinch'],
#  ['use'],
#  ['garnish'],
#  ['gently'],
#  ['stir'],
#  ['combine'],
#  ['cover'],
#  ['pan'],
#  ['stage'],
#  ['coconut'],
#  ['milk'],
#  ['curdle'],
#  ['soon'],
#  ['prawns'],
#  ['pink'],
#  ['cooked'],
#  ['minutes'],
#  ['add'],
#  ['ghee'],
#  ['remove'],
#  ['pan'],
#  ['heat'],
#  ['sprinkle'],
#  ['reserved'],
#  ['garam'],
#  ['masala'],
#  ['dish'],
#  ['serve'],
#  ['shellys'],
#  ['meat'],
#  ['curry'],
#  ['water'],
#  ['beef'],
#  ['ginger'],
#  ['turmeric'],
#  ['bay'],
#  ['leaf'],
#  ...]

# %%
df_I = df_top5[df_top5['region'].isin(['Italian'])]
df_M = df_top5[df_top5['region'].isin(['Mexican'])]
df_SA = df_top5[df_top5['region'].isin(['South American'])]
df_C = df_top5[df_top5['region'].isin(['Canadian'])]
df_IS = df_top5[df_top5['region'].isin(['Indian Subcontinent'])]

# %%
fasttext_model = FastText(sentences, vector_size=768, window=5, min_count=1, workers=4, sg=1)
fasttext_model.train(sentences, total_examples=len(sentences), epochs=50)
# Out:
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# (181141276, 221370800)

# %%
fasttext_model.save("/content/drive/MyDrive/BTP: Novel Recipe Generation (Constraint Optimization) 2023/Models/fasttext_model.model")

# %%
fasttext_model.vector_size
# Out:
# 768

# %%
def generate_embedding(words, model):
    embedding = np.zeros(model.vector_size)
    count = 0
    for word in words:
        if word in model.wv:
            embedding += model.wv[word]
            count += 1
    if count > 0:
        embedding /= count
    return embedding

# %%
recipe_embeddings = {}
for index, row in df_top5.iterrows():
    words = row['preprocessed_title'] + \
            [word for ingredient in row['preprocessed_ingredients'] for word in ingredient] + \
            [word for instruction in row['preprocessed_instructions'] for word in instruction]
    recipe_embedding = generate_embedding(words, fasttext_model)
    recipe_embeddings[row['ID']] = recipe_embedding

# %%
def generate_region_embeddings(df, recipe_embeddings):
    region_embeddings = {}
    for region in df['region'].unique():
        region_recipes = df[df['region'] == region]
        region_embedding = np.mean([recipe_embeddings[recipe_id] for recipe_id in region_recipes['ID']], axis=0)
        region_embeddings[region] = region_embedding
    return region_embeddings

# %%
region_embeddings = generate_region_embeddings(df_top5, recipe_embeddings)
region_embeddings
# Out:
# {'Indian Subcontinent': array([ 1.53933063e-05, -1.67834507e-05, -3.75845783e-06, -1.39243155e-05,
#         -1.17192722e-05,  1.54895435e-05,  1.44554904e-05,  8.70576527e-06,
#          2.01836251e-06,  1.06920985e-05,  2.63285192e-05,  2.91191235e-05,
#         -1.42643373e-06,  3.69212600e-06,  1.62767355e-05,  1.77969398e-05,
#          2.36989906e-05,  9.13844320e-06,  4.38213877e-06, -8.33801132e-06,
#         -3.30907797e-05,  3.67414364e-05, -1.56020746e-06, -2.43026089e-05,
#          2.55065918e-05, -2.87271521e-05, -6.35884722e-07,  1.09647336e-06,
#         -5.73876496e-06,  2.36114529e-05,  9.54337992e-06,  1.52696129e-05,
#          2.37381852e-05,  8.64995156e-06,  1.69134592e-05, -5.87890442e-06,
#          3.10646987e-05,  6.78666468e-06, -4.43011309e-05, -2.41433436e-05,
#          2.34592722e-05,  1.86284322e-05, -2.72964169e-05, -3.65645746e-05,
#          1.72060996e-06,  5.17008516e-06, -7.66100418e-06,  1.39935288e-05,
#         -1.93571291e-05,  3.40649789e-05, -5.07006747e-05, -2.27551708e-06,
#         -3.39620028e-05, -2.08938036e-05, -2.35237270e-06,  3.25238782e-05,
#          1.67234155e-05,  1.16133042e-05, -3.54563237e-05,  1.98475434e-05,
#         -2.82059249e-05,  7.64861894e-07,  1.35231657e-06,  1.35869852e-05,
#          2.62241987e-06, -6.30221739e-06, -2.97452596e-05,  9.33739673e-06,
#         -2.97477617e-05, -1.87278597e-05, -9.10936764e-06, -1.61082996e-05,
#         -5.11489471e-06, -2.83441880e-05,  8.69056212e-06, -1.72513036e-05,
#         -4.52461453e-06,  2.35322302e-05,  8.20301862e-06,  9.76644695e-06,
#          1.07138913e-05, -3.18078407e-06,  4.82572761e-06,  1.95413144e-05,
#         -4.99184850e-06,  7.89795694e-06,  1.40461346e-06, -5.91880882e-06,
#         -1.91669433e-05,  4.14014166e-06,  2.46147666e-05,  2.84639256e-06,
#          3.00010388e-05,  5.20796689e-06, -8.66164972e-07, -2.87473636e-05,
#         -2.29096630e-06,  3.08615181e-05,  2.51008356e-05,  1.91559146e-05,
#         -6.42404505e-06, -8.13012156e-06,  2.73554387e-06, -1.73325248e-05,
#         -2.43374328e-05,  2.36168685e-05, -5.71930051e-06,  1.26819598e-05,
#         -1.62633249e-05,  2.61725296e-06, -6.46018700e-06,  1.38488521e-05,
#         -7.04100075e-06,  2.34458360e-05, -2.30063154e-05,  1.71416600e-06,
#          7.97948174e-06, -2.03740269e-05, -2.89088976e-05,  1.78398422e-05,
#         -1.20057359e-05,  2.25685365e-06, -1.41810017e-05, -8.89365103e-06,
#         -8.25073663e-06, -5.16244517e-06,  5.47490609e-07, -1.34363212e-05,
#         -5.26639139e-06,  3.13422071e-06, -4.01931946e-05, -1.10765967e-05,
#         -3.64144793e-06, -3.38072535e-05,  2.08069227e-05, -4.12503082e-05,
#          1.88308509e-05,  2.51363554e-08, -2.39705338e-05, -4.05369474e-06,
#          5.96300530e-06, -2.99362751e-05, -1.25048873e-05, -4.27672094e-06,
#          3.00095444e-05, -1.22931885e-05,  1.42785642e-05,  2.20138048e-05,
#         -5.35319291e-06,  1.14820322e-05, -1.95986171e-05, -9.71921618e-06,
#         -2.21328707e-05,  2.44165541e-05, -3.18834427e-06, -7.94427281e-06,
#         -8.20940205e-06, -3.82936822e-05, -2.28045709e-05,  8.39369696e-06,
#         -4.98281357e-06, -2.66415669e-05,  2.84768606e-06,  3.05396261e-05,
#         -4.40101519e-05, -1.15976460e-05,  1.61639058e-05,  9.92317092e-06,
#          3.15936486e-05, -1.45599712e-05, -6.11680177e-07,  2.74364686e-06,
#         -4.94079186e-06, -7.03555672e-06, -3.33082324e-05, -3.67584539e-06,
#          3.10557075e-06,  3.12454643e-05, -2.26342059e-05, -6.29840923e-06,
#         -1.94772578e-05, -5.48316008e-06, -2.91437297e-05, -7.11103561e-07,
#          1.69895954e-05,  1.33709262e-05,  1.22778071e-05, -4.58680737e-06])}

# %%
embeddings_df = pd.DataFrame(region_embeddings).T
cosine_sim_matrix = cosine_similarity(embeddings_df)
cosine_sim_df = pd.DataFrame(cosine_sim_matrix, index=embeddings_df.index, columns=embeddings_df.index)

cosine_sim_df
# Out:
#                      Indian Subcontinent   Mexican  South American   Italian  \
# Indian Subcontinent             1.000000  0.885407        0.814704  0.883025
# Mexican                         0.885407  1.000000        0.845332  0.903351
# South American                  0.814704  0.845332        1.000000  0.845243
# Italian                         0.883025  0.903351        0.845243  1.000000
# Canadian                        0.877067  0.908628        0.826657  0.921304
#
#                      Canadian
# Indian Subcontinent  0.877067
# Mexican              0.908628
# South American       0.826657
# Italian              0.921304
# Canadian             1.000000

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import random

# Number of iterations for averaging
num_iterations = 300

# Initialize a variable to sum the cosine similarity matrices
sum_similarity_matrix = None

for _ in range(num_iterations):
    selected_embeddings = []

    for region in ['Italian', 'Mexican', 'South American', 'Canadian', 'Indian Subcontinent']:
        # Filter embeddings for the current region
        region_embedding_ids = [id for id in df_top5[df_top5['region'] == region]['ID'] if id in recipe_embeddings]

        # Randomly select one embedding index
        if region_embedding_ids:
            selected_id = random.choice(region_embedding_ids)
            selected_embedding = recipe_embeddings[selected_id]
            selected_embeddings.append(selected_embedding)

    # Check if the correct number of embeddings are selected
    if len(selected_embeddings) == 5:  # 5 for five regions
        # Compute cosine similarity matrix for selected embeddings
        current_similarity_matrix = cosine_similarity(selected_embeddings)

        # Sum the similarity matrices
        if sum_similarity_matrix is None:
            sum_similarity_matrix = current_similarity_matrix
        else:
            sum_similarity_matrix += current_similarity_matrix

# Calculate the average cosine similarity matrix
average_similarity_matrix = sum_similarity_matrix / num_iterations

# %%
regions = ['Italian', 'Mexican', 'South American', 'Canadian', 'Indian Subcontinent']

# %%
print("Average Cosine Similarity Matrix:")
# Print header
print(" " * 20, end="")  # Adjust spacing based on your needs
for region in regions:
    print(f"{region:>20}", end="")  # Format for better alignment
print()

# Print each row with the region label
for i, region_row in enumerate(regions):
    print(f"{region_row:>20}", end="")  # Region label
    for sim in average_similarity_matrix[i]:
        print(f"{sim:>20.4f}", end="")  # Similarity values formatted to 4 decimal places
    print()
# Out:
# Average Cosine Similarity Matrix:
#                                  Italian             Mexican      South American            Canadian Indian Subcontinent
#              Italian              1.0000              0.2354              0.2650              0.2238              0.2632
#              Mexican              0.2354              1.0000              0.2453              0.2148              0.2529
#       South American              0.2650              0.2453              1.0000              0.2243              0.2653
#             Canadian              0.2238              0.2148              0.2243              1.0000              0.2273
#  Indian Subcontinent              0.2632              0.2529              0.2653              0.2273              1.0000

# %% [markdown]
# ### Clustering

# %% [markdown]
# 10 clusters

# %%
from sklearn.cluster import KMeans

# Assuming recipe_embeddings is a dictionary with recipe IDs as keys and embeddings as values
embeddings = list(recipe_embeddings.values())  # Extracting embeddings

# Decide on the number of clusters
n_clusters = 10  # for example

# Perform clustering
kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(embeddings)

# Getting cluster labels
cluster_labels = kmeans.labels_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Assuming the index of df_balanced corresponds to the keys in recipe_embeddings
df_top5['cluster'] = cluster_labels
# Out:
# <ipython-input-24-85e802956cf3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_top5['cluster'] = cluster_labels

# %%
# Group by cluster and then calculate the percentage of each region
cluster_region_distribution = df_top5.groupby('cluster')['region'].value_counts(normalize=True) * 100

# %%
cluster_region_distribution
# Out:
# cluster  region
# 0        Mexican                55.136437
#          Canadian               16.211878
#          Italian                11.235955
#          Indian Subcontinent    10.433387
#          South American          6.982343
# 1        Italian                37.568157
#          Indian Subcontinent    28.598691
#          Mexican                16.425845
#          South American          9.487459
#          Canadian                7.919847
# 2        Mexican                58.786611
#          Indian Subcontinent    12.395397
#          Canadian               11.480126
#          Italian                11.349372
#          South American          5.988494
# 3        Canadian               40.048229
#          Italian                29.567798
#          Mexican                15.952513
#          Indian Subcontinent     9.905398
#          South American          4.526062
# 4        South American         75.853549
#          Mexican                11.949686
#          Italian                 8.602875
#          Canadian                2.515723
#          Indian Subcontinent     1.078167
# 5        Italian                33.571186
#          Mexican                25.087779
#          Canadian               17.249972
#          South American         12.708121
#          Indian Subcontinent    11.382943
# 6        Italian                38.270688
#          Mexican                25.241420
#          Indian Subcontinent    20.650721
#          South American          9.196256
#          Canadian                6.640915
# 7        Mexican                50.201084
#          Italian                34.079385
#          Canadian                7.711138
#          South American          7.413884
#          Indian Subcontinent     0.594510
# 8        Mexican                45.601589
#          Italian                28.461975
#          Indian Subcontinent    13.904654
#          Canadian                9.421112
#          South American          2.610670
# 9        Italian                64.579939
#          Mexican                12.171282
#          Canadian               10.658599
#          South American          6.539446
#          Indian Subcontinent     6.050733
# Name: region, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert the Series to a DataFrame for easier plotting
cluster_region_distribution_df = cluster_region_distribution.reset_index(name='percentage')

# Pivot the DataFrame to have regions as columns and clusters as rows
pivot_df = cluster_region_distribution_df.pivot(index='cluster', columns='region', values='percentage').fillna(0)

# Plot
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_df, annot=True, cmap="YlGnBu")
plt.title('Percentage Distribution of Regions in Each Cluster')
plt.xlabel('Region')
plt.ylabel('Cluster')
plt.show()

# %% [markdown]
# 5 clusters

# %%
from sklearn.cluster import KMeans

# Assuming recipe_embeddings is a dictionary with recipe IDs as keys and embeddings as values
embeddings = list(recipe_embeddings.values())  # Extracting embeddings

# Decide on the number of clusters
n_clusters = 5  # for example

# Perform clustering
kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(embeddings)

# Getting cluster labels
cluster_labels = kmeans.labels_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Assuming the index of df_balanced corresponds to the keys in recipe_embeddings
df_top5['cluster'] = cluster_labels
# Out:
# <ipython-input-29-85e802956cf3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_top5['cluster'] = cluster_labels

# %%
# Group by cluster and then calculate the percentage of each region
cluster_region_distribution = df_top5.groupby('cluster')['region'].value_counts(normalize=True) * 100

# %%
cluster_region_distribution
# Out:
# cluster  region
# 0        Mexican                34.919473
#          Italian                33.803075
#          Indian Subcontinent    12.490849
#          Canadian               11.786237
#          South American          7.000366
# 1        South American         72.287674
#          Mexican                13.293476
#          Italian                 9.864603
#          Canadian                3.340953
#          Indian Subcontinent     1.213293
# 2        Canadian               32.760572
#          Italian                27.050108
#          Mexican                21.627739
#          Indian Subcontinent    12.614467
#          South American          5.947114
# 3        Mexican                45.972554
#          Italian                38.116547
#          Canadian                9.118934
#          South American          5.350040
#          Indian Subcontinent     1.441925
# 4        Italian                39.153687
#          Indian Subcontinent    24.453506
#          Mexican                21.057557
#          South American          7.881543
#          Canadian                7.453707
# Name: region, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert the Series to a DataFrame for easier plotting
cluster_region_distribution_df = cluster_region_distribution.reset_index(name='percentage')

# Pivot the DataFrame to have regions as columns and clusters as rows
pivot_df = cluster_region_distribution_df.pivot(index='cluster', columns='region', values='percentage').fillna(0)

# Plot
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_df, annot=True, cmap="YlGnBu")
plt.title('Percentage Distribution of Regions in Each Cluster')
plt.xlabel('Region')
plt.ylabel('Cluster')
plt.show()
