# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import nltk
from nltk.translate.bleu_score import corpus_bleu
nltk.download('punkt')
import random
import os
import re
import pandas as pd
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# Assuming the files are named consistently and located in the directories provided,
# let's first define the file paths for each cuisine's data file.
# Please note that you will need to adjust the paths according to your actual directory structure on Google Colab.

# Define the paths to the directories containing the CSV files
output_df_dir = '/content/drive/MyDrive/BTP_Dev/Output_DF'
final_df_dir = '/content/drive/MyDrive/BTP_Dev/Final_DF'

# List the filenames based on the provided screenshot
file_names = [
    'NovelRecipesGenerated_CANADIAN.csv',
    'NovelRecipesGenerated_SOUTH AMERICAN.csv',
    'NovelRecipesGenerated_INDIAN SUBCONTINENT.csv',
    'NovelRecipesGenerated_MEXICAN.csv',
    'NovelRecipesGenerated_ITALIAN.csv'
]

# Initialize an empty dataframe to combine all the recipes
combined_recipes = pd.DataFrame()

# Loop through each file and append its contents to the combined dataframe
for file_name in file_names:
    # Construct the full file path for the output and final directories
    output_file_path = os.path.join(output_df_dir, file_name)
    final_file_path = os.path.join(final_df_dir, file_name)

    # Check if the file exists in the output directory
    if os.path.isfile(output_file_path):
        # Read the CSV file and combine
        recipes_df = pd.read_csv(output_file_path)
        combined_recipes = combined_recipes.append(recipes_df, ignore_index=True)
    # Check if the file exists in the final directory
    elif os.path.isfile(final_file_path):
        # Read the CSV file and combine
        recipes_df = pd.read_csv(final_file_path)
        combined_recipes = combined_recipes.append(recipes_df, ignore_index=True)
    else:
        print(f"File not found: {file_name}")

# Now let's preprocess the data to make it human-readable
# We will define a function to clean up and structure the recipe text

def clean_recipe(row):
    # Combining the 'Random Ingredients', 'Recipe Title', 'Ingredient Phrases', 'Recipe Instructions' into a formatted string
    formatted_recipe = f"Title: {row['Recipe Title']}\n\n"
    formatted_recipe += "Ingredients:\n"
    if not pd.isna(row['Random Ingredients']):
        ingredients = row['Random Ingredients'].split(';')
        for ingredient in ingredients:
            if ingredient.strip():
                formatted_recipe += f"- {ingredient.strip().capitalize()}\n"
    if not pd.isna(row['Ingredient Phrases']):
        ingredient_phrases = row['Ingredient Phrases'].split('|')
        for phrase in ingredient_phrases:
            if phrase.strip():
                formatted_recipe += f"- {phrase.strip().capitalize()}\n"
    formatted_recipe += "\nInstructions:\n"
    if not pd.isna(row['Recipe Instructions']):
        instructions = row['Recipe Instructions'].split('.')
        for instruction in instructions:
            if instruction.strip():
                formatted_recipe += f"{instruction.strip().capitalize()}.\n"
    return formatted_recipe

# Apply the cleaning function to each row in the dataframe
combined_recipes['Formatted Recipe'] = combined_recipes.apply(clean_recipe, axis=1)

# Show the cleaned and formatted recipes
combined_recipes['Formatted Recipe'].head()
# Out:
# <ipython-input-4-9ee965c06e58>:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_recipes = combined_recipes.append(recipes_df, ignore_index=True)
# <ipython-input-4-9ee965c06e58>:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_recipes = combined_recipes.append(recipes_df, ignore_index=True)
# <ipython-input-4-9ee965c06e58>:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_recipes = combined_recipes.append(recipes_df, ignore_index=True)
# <ipython-input-4-9ee965c06e58>:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_recipes = combined_recipes.append(recipes_df, ignore_index=True)
# <ipython-input-4-9ee965c06e58>:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_recipes = combined_recipes.append(recipes_df, ignore_index=True)
# 0    Title:  Barley And Chocolate Biscotti \n\n\nIn...
# 1    Title:  Hot and Spicy Creamy Corn Dip \n\n\nIn...
# 2    Title:  Wild Rice Paneer \n\n\nIngredients:\n-...
# 3    Title:  Smoked Bacon Penne \n\n\nIngredients:\...
# 4    Title:  Mexican Orzo for Two \n\n\nIngredients...
# Name: Formatted Recipe, dtype: object

# %%
combined_recipes
# Out:
#                                    Random Ingredients  \
# 0   milk chocolate chip,parmesan cheese,vegetable,...
# 1   cumin powder,cream corn,garlic red chile paste...
# 2   pizza dough,savory,wild rice,vanilla essence,b...
# 3                                 penne,pepper flake;
# 4   cheddar cheese,four cheese mexican,nori,grain ...
# 5   raspberry syrup,olive oil,adobo sauce,black be...
# 6   dark sesame oil,ricotta cheese,dijon mustard,l...
# 7   radish,beef roast,pork,baby carrot,salmon fillet;
# 8                            golden syrup,grain rice;
# 9                 white chocolate chip,bamboo skewer;
# 10       apricot,veal,buffalo mozzarella,kidney bean;
# 11                  celery leaf,marjoram,curry paste;
# 12  vanilla extract,extra virgin olive oil,chive,p...
# 13  peach,masa harina,garam masala,brown gravy mix...
# 14  walnut,celery,sourdough bread,grain mustard,tu...
# 15  prune,cooking oat,cream tartar,string bean,ban...
# 16  kidney bean,chickpea,white peppercorn,tea,pork...
# 17  spring onion,sun tomato oil,hot water,chicken ...
# 18                                   half,coffee,ice;
# 19          tomato soup,self raising flour,red onion;
# 20             water chestnut,sesame oil,fish fillet;
# 21  red curry paste,plum tomato,allspice,spaghetti...
# 22                   hamburger,black peppercorn,date;
# 23  rigatoni pasta,coriander,confectioner ' sugar,...
# 24  green mung bean,vegemite,lemon pepper seasonin...
#
#                                          Recipe Title  \
# 0                    Barley And Chocolate Biscotti \n
# 1                    Hot and Spicy Creamy Corn Dip \n
# 2                                 Wild Rice Paneer \n
# 3                               Smoked Bacon Penne \n
# 4                             Mexican Orzo for Two \n
# 5               Easy Crockpot Mexican Rice & Beans \n
# 6                              Baked Lobster Bites \n
# 7                             Italian Salmon Filet \n
# 8                         Quick Breakfast Burritos \n
# 9           Chocolate Bamboo Skewer for Diabetic \n\n
# 10          Nepali Indian Vegetarian Curry (Vegan) \n
# 11            Curried Cauliflower Cilantro Chutney \n
# 12   Vegan and Whole Wheat Stuffed Baked Potato Pe...
# 13                 Mango Peaches With Mango Masala \n
# 14                            Sour Mustard Patties \n
# 15                         Pork and Garlic Burgers \n
# 16                       Ciofi-Style Mexican Bites \n
# 17                       Chunky Chicken Cacciatore \n
# 18                                         Grandma \n
# 19                             Mexican Breadsticks \n
# 20                         Seabiscuit With Seafood \n
# 21   Simple Pineapple Spaghetti Sauce With Pineapp...
# 22                                       Hamburger \n
# 23              Rigatoni With Creamy Sirloin Sauce \n
# 24                Crock Pot Veggie Beef Sandwiches \n
#
#                                    Ingredient Phrases  \
# 0     1 1/2 cups uncooked long-grain barley  |  2 ...
# 1     32 ounces cream-style corn, drained  |  1/4 ...
# 2     1 large raw wild rice  |  1 package cooked b...
# 3     1 lb smoked bacon, chopped  |  1/2 teaspoon ...
# 4     2 lbs uncooked long grain white rice  |  1/2...
# 5     4 cups long grain rice  |  16 ounces black b...
# 6     500 g lobster tails  |  125 g ricotta cheese...
# 7     3 ribs roast  |  1 cup cubed pork breast or ...
# 8     3 tablespoons golden syrup  |  3 cups uncook...
# 9     1 1/2 lbs bamboo skewer  |  1/4 cup white ch...
# 10    2 veal, cut into 16 wedges  |  1 1 lb lean g...
# 11    3 -4 tablespoons garlic fresh curry paste, c...
# 12    1 package firm tofu, firm tofu  |  vegetable...
# 13    1 tablespoon lemon juice zest, from 1 lemon,...
# 14    2 -3 tablespoons thai red curry paste or 2 -...
# 15    1 1/2 lbs cooking oat  |  2 tablespoons cook...
# 16    3 lbs ground pork  |  2 cups beans  |  2 can...
# 17    4 cups hot water  |  1 tablespoon hot water ...
# 18    2 cups half-and-half  |  ice  |  1 cup coffe...
# 19    1/4 pound self-raising flour  |  1 small red...
# 20    2 lbs fish fillets  |  1/2 lb fresh water ch...
# 21    2 tablespoons corn oil  |  3 tablespoons red...
# 22    4 large dates  |  1/2 lb hamburger  |  1/4 c...
# 23    1 lb rigatoni pasta  |  2 lbs sirloin, cut i...
# 24    1 lb vegemite  |  1/4 cup lime pepper season...
#
#                                   Recipe Instructions  \
# 0     bring a large pot of lightly salted water to...
# 1     mix the dried corn with the cream cheese and...
# 2     brown rice in microwave  .    drain and rins...
# 3     heat frying pan to 350f  .    place chopped ...
# 4     cook rice in boiling, salted water according...
# 5     heat a medium saucepan over medium heat  .  ...
# 6     preheat oven to 200c degrees  .    make a we...
# 7     lightly salt and pepper the meat  .    place...
# 8     put rice in a steamer basket and bring water...
# 9     tie the skewer with a bamboo skewer and heat...
# 10    place veal as it is in a large, oven proof c...
# 11    mix together the garlic cilantro, cumin, mar...
# 12    preheat oven to 350 degrees  .    spray baki...
# 13    in a blender or food processor, blend the ma...
# 14    in a mixer bowl mix the thai chutney, mustar...
# 15    place pork, oat, and sour cream and prunes i...
# 16    brown the ground pork and drain on paper tow...
# 17    bring boiling water to a boil over high heat...
# 18    place half the coffee into a blender  .    a...
# 19    preheat oven to 350 degrees f  .    mix flou...
# 20    place fish fillets in large resealable plast...
# 21    heat 2 tablespoons corn oil in a pot over me...
# 22    cut 2 slices from hamburger  .    if making ...
# 23    bring a large pot of lightly salted water to...
# 24    in a skillet cook mung beans until slightly ...
#
#                                      Formatted Recipe
# 0   Title:  Barley And Chocolate Biscotti \n\n\nIn...
# 1   Title:  Hot and Spicy Creamy Corn Dip \n\n\nIn...
# 2   Title:  Wild Rice Paneer \n\n\nIngredients:\n-...
# 3   Title:  Smoked Bacon Penne \n\n\nIngredients:\...
# 4   Title:  Mexican Orzo for Two \n\n\nIngredients...
# 5   Title:  Easy Crockpot Mexican Rice & Beans \n\...
# 6   Title:  Baked Lobster Bites \n\n\nIngredients:...
# 7   Title:  Italian Salmon Filet \n\n\nIngredients...
# 8   Title:  Quick Breakfast Burritos \n\n\nIngredi...
# 9   Title:  Chocolate Bamboo Skewer for Diabetic \...
# 10  Title:  Nepali Indian Vegetarian Curry (Vegan)...
# 11  Title:  Curried Cauliflower Cilantro Chutney \...
# 12  Title:  Vegan and Whole Wheat Stuffed Baked Po...
# 13  Title:  Mango Peaches With Mango Masala \n\n\n...
# 14  Title:  Sour Mustard Patties \n\n\nIngredients...
# 15  Title:  Pork and Garlic Burgers \n\n\nIngredie...
# 16  Title:  Ciofi-Style Mexican Bites \n\n\nIngred...
# 17  Title:  Chunky Chicken Cacciatore \n\n\nIngred...
# 18  Title:  Grandma \n\n\nIngredients:\n- Half,cof...
# 19  Title:  Mexican Breadsticks \n\n\nIngredients:...
# 20  Title:  Seabiscuit With Seafood \n\n\nIngredie...
# 21  Title:  Simple Pineapple Spaghetti Sauce With ...
# 22  Title:  Hamburger \n\n\nIngredients:\n- Hambur...
# 23  Title:  Rigatoni With Creamy Sirloin Sauce \n\...
# 24  Title:  Crock Pot Veggie Beef Sandwiches \n\n\...

# %%
combined_recipes.to_csv('/content/combined_recipes.csv')

# %%
def read_and_preprocess(file_path):
    """Read and preprocess the data from a file, preserving special tokens."""
    with open(file_path, 'r') as file:
        data = file.readlines()
    return data

def sample_data(data, num_samples=50):
    """Sample a specific number of data points from the data."""
    return random.sample(data, min(num_samples, len(data)))

def calculate_bleu_scores(candidates, references):
    """Calculate BLEU scores for each set of candidates against the references."""
    tokenized_candidates = [nltk.word_tokenize(c.lower()) for c in candidates]
    tokenized_references = [[nltk.word_tokenize(ref.lower())] for ref in references]
    return corpus_bleu(tokenized_references, tokenized_candidates)

# Reading and preprocessing the training data
train_file = '/content/drive/MyDrive/BTP_Dev/Dataset/train_temp.txt'
train_data = read_and_preprocess(train_file)

# Paths to the generated recipe files
generated_files = [
    '/content/drive/MyDrive/BTP_Dev/Output_DF/NovelRecipesGenerated_CHINESE_processed.txt',
    '/content/drive/MyDrive/BTP_Dev/Output_DF/NovelRecipesGenerated_INDIAN_processed.txt',
    '/content/drive/MyDrive/BTP_Dev/Output_DF/NovelRecipesGenerated_ITALIAN_processed.txt',
    '/content/drive/MyDrive/BTP_Dev/Output_DF/NovelRecipesGenerated_MEXICAN_processed.txt',
    '/content/drive/MyDrive/BTP_Dev/Output_DF/NovelRecipesGenerated_SOUTHERN_processed.txt'
]

# Sampling and calculating BLEU scores
bleu_scores = {}
for file_path in generated_files:
    generated_data = read_and_preprocess(file_path)
    sampled_train_data = sample_data(train_data)
    sampled_generated_data = sample_data(generated_data)
    score = calculate_bleu_scores(sampled_generated_data, sampled_train_data)
    bleu_scores[file_path] = score

# Printing BLEU scores
for file, score in bleu_scores.items():
    print(f"{file}: BLEU Score = {score}")
# Out:
# /content/drive/MyDrive/BTP_Dev/Output_DF/NovelRecipesGenerated_CHINESE_processed.txt: BLEU Score = 4.621967646086874e-12
# /content/drive/MyDrive/BTP_Dev/Output_DF/NovelRecipesGenerated_INDIAN_processed.txt: BLEU Score = 1.8546376311654376e-11
# /content/drive/MyDrive/BTP_Dev/Output_DF/NovelRecipesGenerated_ITALIAN_processed.txt: BLEU Score = 2.6844903311191096e-12
# /content/drive/MyDrive/BTP_Dev/Output_DF/NovelRecipesGenerated_MEXICAN_processed.txt: BLEU Score = 8.975555254625472e-09
# /content/drive/MyDrive/BTP_Dev/Output_DF/NovelRecipesGenerated_SOUTHERN_processed.txt: BLEU Score = 1.1008823788114727e-18
